# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Rakshith**
# Data Engineer

# %% [markdown]
# *I am interested in data science because i would love to contibute to wards the analysis and profitability in stock market*

# %% [markdown]
# ### The below code prints the Square of 5

# %%
print(5**2)
# Out:
# 25

# %% [markdown]
#     1.Numbered list 1
#     2.Numbered list 2
#     3.Numbered list 3
#         3a.Numbered Sublist 3a
#         3b.Numbered Sublist 3b
#
# ***
#     - Bullet list 1
#     - Bullet List 2
#
# ***
# [UTF-8 Geometric Shapes](https://www.w3schools.com/charsets/ref_utf_geometric.asp)
#
# | Heading | Heading |
# | ----| ----|
# | text   | text |
# | text | text |
